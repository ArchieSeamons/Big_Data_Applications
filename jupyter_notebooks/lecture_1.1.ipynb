# %% [markdown]
# **Homework**
# * Get familiar with VS code
# * Spend time on GitHub
# * familiarise with markdown syntax
# * Practice pushing from VS to Github

# %%
print('Hello World!')
print(2+2)
week_day='Thursday'
print(f'Today is {week_day}')

# %%
a=5
my_object={"flat":20,"type":"residential"}
my_list=[1,2,3,4,5]

# %%
a=input("tell me something")
print("you've just entered",a)
