# %% [markdown]
# # **Lecture 2.1**
#
# * `while` loop
# * complex data types
# * `for` loops
# * loop control
#
# Note: never leave commented out code in the final product.

# %%
count = 0

while count <= 10:
    print(f"count is: {count}")
    count += 2

print("loop finished!")

# %%
while True:
    print("I am always true")

# %%
n = 5
for i in range(n):
    for j in range(n):
        print("O",end = " ")
    print()

# %%
n = 5 
for i in range(n):
    for j in range(i+1):
        print("O", end=" ")
    print()

# %% [markdown]
# # Part 2 - Importing Libraries and Modules

# %%
import math

a = s(4)
a
